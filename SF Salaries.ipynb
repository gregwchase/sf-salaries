# %%
import pandas as pd
import numpy as np

# %%
salaries = pd.read_csv("Salaries.csv")

# %%
salaries.head()
# Out:
#    Id       EmployeeName                                        JobTitle  \
# 0   1     NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1   2       GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
# 2   3     ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
# 3   4  CHRISTOPHER CHONG            WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4   5    PATRICK GARDNER    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
#
#   BasePay OvertimePay OtherPay Benefits   TotalPay  TotalPayBenefits  Year  \
# 0  167411           0   400184      NaN  567595.43         567595.43  2011
# 1  155966      245132   137811      NaN  538909.28         538909.28  2011
# 2  212739      106088  16452.6      NaN  335279.91         335279.91  2011
# 3   77916     56120.7   198307      NaN  332343.61         332343.61  2011
# 4  134402        9737   182235      NaN  326373.19         326373.19  2011
#
#    Notes         Agency Status
# 0    NaN  San Francisco    NaN
# ...

# %%
salaries.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 148654 entries, 0 to 148653
# Data columns (total 13 columns):
# Id                  148654 non-null int64
# EmployeeName        148654 non-null object
# JobTitle            148654 non-null object
# BasePay             147174 non-null object
# OvertimePay         82551 non-null object
# OtherPay            113436 non-null object
# Benefits            111442 non-null object
# TotalPay            148286 non-null float64
# TotalPayBenefits    148624 non-null float64
# Year                148654 non-null int64
# Notes               0 non-null float64
# Agency              148654 non-null object
# Status              38119 non-null object
# dtypes: float64(3), int64(2), object(8)
# memory usage: 14.7+ MB

# %%
salaries.fillna(0)
# Out:
#             Id            EmployeeName  \
# 0            1          NATHANIEL FORD
# 1            2            GARY JIMENEZ
# 2            3          ALBERT PARDINI
# 3            4       CHRISTOPHER CHONG
# 4            5         PATRICK GARDNER
# 5            6          DAVID SULLIVAN
# 6            7               ALSON LEE
# 7            8           DAVID KUSHNER
# 8            9          MICHAEL MORRIS
# 9           10      JOANNE HAYES-WHITE
# 10          11           ARTHUR KENNEY
# 11          12        PATRICIA JACKSON
# 12          13       EDWARD HARRINGTON
# 13          14             JOHN MARTIN
# 14          15          DAVID FRANKLIN
# 15          16         RICHARD CORRIEA
# 16          17                AMY HART
# 17          18          SEBASTIAN WONG
# 18          19              MARTY ROSS
# 19          20           ELLEN MOFFATT
# 20          21              VENUS AZAR
# 21          22            JUDY MELINEK
# 22          23           GEORGE GARCIA
# ...

# %%
salaries["BasePay"] = pd.to_numeric(salaries["BasePay"])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-68-760f4f58f9d2> in <module>()
# ----> 1 salaries["BasePay"] = pd.to_numeric(salaries["BasePay"])
#
# //anaconda/lib/python2.7/site-packages/pandas/tools/util.pyc in to_numeric(arg, errors, downcast)
#     193             coerce_numeric = False if errors in ('ignore', 'raise') else True
#     194             values = lib.maybe_convert_numeric(values, set(),
# --> 195                                                coerce_numeric=coerce_numeric)
#     196
#     197     except Exception:
#
# pandas/src/inference.pyx in pandas.lib.maybe_convert_numeric (pandas/lib.c:56097)()
#
# ValueError: Unable to parse string "Not Provided" at position 148646

# %%
salaries = salaries.replace(0,np.NaN)

# %%
salaries.BasePay.head()
# Out:
# 0    167411
# 1    155966
# 2    212739
# 3     77916
# 4    134402
# Name: BasePay, dtype: object

# %%
salaries.Agency.value_counts()
# Out:
# San Francisco    148654
# Name: Agency, dtype: int64

# %%
salaries.Year.value_counts()
# Out:
# 2014    38123
# 2013    37606
# 2012    36766
# 2011    36159
# Name: Year, dtype: int64

# %%
salaries.Status.value_counts()
#Include NaN values when counting? Should be considered another category.
#Change missing values to "-1"?
# Out:
# FT    22334
# PT    15785
# Name: Status, dtype: int64

# %%
len(salaries)
# Out:
# 148654

# %%
salaries.BasePay.value_counts()
# Out:
# 0.00         423
# 54703.00     327
# 55026.0      297
# 48472.4      210
# 65448.0      153
# 121068.0     152
# 68391.0      152
# 88374.0      151
# 51492.8      143
# 94191.0      137
# 116584.0     127
# 105934.66    117
# 105934.67    114
# 51502.0      110
# 67948.0      109
# 63995.0      103
# 60206.6      101
# 86840.0       95
# 105934.65     94
# 72144.0       86
# 116956.71     85
# 81830.0       84
# 79222.0       82
# 88062.0       82
# 112703.74     79
# 83160.0       77
# 61128.0       77
# 109783.86     74
# 57630.6       73
# 77580.4       71
#             ...
# 69095.97       1
# 88825.96       1
# 97848.32       1
# 33100.35       1
# 90174.48       1
# 64900.3        1
# 61086.21       1
# 19265.11       1
# 76659.2        1
# 149921.21      1
# 81442.28       1
# 61995.8        1
# 7348.12        1
# 181955.77      1
# 9600.97        1
# 93386.26       1
# 103975.81      1
# 13713.47       1
# 88886.04       1
# 87018.3        1
# 65646.58       1
# ...
